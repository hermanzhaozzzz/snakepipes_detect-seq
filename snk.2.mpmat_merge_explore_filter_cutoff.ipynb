# %%
# Out:
# [['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-10',
#   'SMR-0.01',
#   'RPN-2',
#   'RTN-2',
#   '293T-bat_GBEmini-AP-RNF2-All-PD_rep1_hg38.filtered_SMN-1_SCN-10_SMR-0.01_RPN-2_RTN-2.C2T.mpmat'],
#  ['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-10',
#   'SMR-0.01',
#   'RPN-2',
#   'RTN-2',
#   '293T-bat_GBEmini-AP-RNF2-All-PD_rep1_hg38.filtered_SMN-1_SCN-10_SMR-0.01_RPN-2_RTN-2.G2A.mpmat'],
#  ['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-10',
#   'SMR-0.1',
#   'RPN-2',
#   'RTN-2',
#   '293T-bat_GBEmini-AP-RNF2-All-PD_rep1_hg38.filtered_SMN-1_SCN-10_SMR-0.1_RPN-2_RTN-2.C2T.mpmat'],
#  ['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-10',
#   'SMR-0.1',
#   'RPN-2',
#   'RTN-2',
#   '293T-bat_GBEmini-AP-RNF2-All-PD_rep1_hg38.filtered_SMN-1_SCN-10_SMR-0.1_RPN-2_RTN-2.G2A.mpmat'],
# ...
