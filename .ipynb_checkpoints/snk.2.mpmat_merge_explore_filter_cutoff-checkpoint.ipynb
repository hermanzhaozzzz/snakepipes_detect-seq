# %%
import os
import pandas as pd

# %%
ls = [i for i in os.listdir('../mpmat_filter/') if '.mpmat' in i]
ls.sort()
ls = [i[:-10].replace('.mpmat','').split('_') for i in ls]
# # for subls in ls:
# #     subls = [i for i in subls]
# ls = [i[:3] + i[4:] for i in ls]
# df = pd.DataFrame(ls)
# df = df.iloc[:,[1,2,3,4,5,6,7]].copy()
ls = [i[:3] i in ls]
# Out:
# [['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-10',
#   'SMR-0.01',
#   'RPN-2',
#   'RTN-2'],
#  ['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-10',
#   'SMR-0.01',
#   'RPN-2',
#   'RTN-2'],
#  ['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-10',
#   'SMR-0.1',
#   'RPN-2',
#   'RTN-2'],
#  ['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-10',
#   'SMR-0.1',
#   'RPN-2',
#   'RTN-2'],
#  ['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-5',
#   'SMR-0.01',
#   'RPN-2',
#   'RTN-2'],
#  ['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-5',
#   'SMR-0.01',
#   'RPN-2',
#   'RTN-2'],
#  ['293T-bat',
#   'GBEmini-AP-RNF2-All-PD',
#   'rep1',
#   'hg38.filtered',
#   'SMN-1',
#   'SCN-5',
# ...
